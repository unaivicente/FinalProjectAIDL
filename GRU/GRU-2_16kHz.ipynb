# %% [markdown]
# # GRU-2
#
# ## Hyperparameter tuning
#
# - 1D convolutional layer + batch normalization + maxPooling : 4
#
# - Hidden dimension : 128
#
# - Number of channels : 128
#
# - Loss function : Negative Log Likelihood
#
# - Training epochs : 40
#
# - Batch size : 50
#
# - Learning rate : 0.01
#
# - Optimizer : SGD with 0.0001 weight decay and StepLR that decays the LR of each parameter group by 0.1 each 20 epochs.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchaudio
import sys

import numpy as np

import math

import matplotlib.pyplot as plt
import IPython.display as ipd

from tqdm import tqdm

from torchaudio.datasets import SPEECHCOMMANDS
import os

# %%
#Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Split of the dataset and data preparation
# The class SubsetSC splits the Speech Commands Dataset into train, validation and test sets. The classification of the audio files in each set is specified in the 'validation.txt' and 'testing.txt' files where are written the paths of them.

# %%
class SubsetSC(SPEECHCOMMANDS):
    def __init__(self, subset: str = None):
        super().__init__("./", download=True)

        def load_list(filename):
            filepath = os.path.join(self._path, filename)
            with open(filepath) as fileobj:
                return [os.path.normpath(os.path.join(self._path, line.strip())) for line in fileobj]

        if subset == "validation":
            self._walker = load_list("validation_list.txt")
        elif subset == "testing":
            self._walker = load_list("testing_list.txt")
        elif subset == "training":
            excludes = load_list("validation_list.txt") + load_list("testing_list.txt")
            excludes = set(excludes)
            self._walker = [w for w in self._walker if w not in excludes]

# %%
# Create training, validation and testing split of the data
train_set = SubsetSC("training")
val_set = SubsetSC("validation")
test_set = SubsetSC("testing")

#Tuple made of waveform, sample rate, label (spoken word), speaker ID and number of the utterance.
waveform, sample_rate, label, speaker_id, utterance_number = train_set[0]
# Out:
#   0%|          | 0.00/2.26G [00:00<?, ?B/s]

# %%
#List of labels in the dataset (commands said by speakers)
labels = sorted(list(set(datapoint[2] for datapoint in train_set)))

# %%
def label_to_index(word):
    # Return the position of the word in labels
    return torch.tensor(labels.index(word))


def index_to_label(index):
    # Return the word corresponding to the index in labels
    # This is the inverse of label_to_index
    return labels[index]

# %% [markdown]
# # Batched tensors for the model
# To transform an array of data point made of audio and labels into two batched tensors for the model. The function collate_fn is used by the PyTorch DataLoader that allows us to iterate over a dataset by batches.

# %%
def pad_sequence(batch):
    # Make all tensor in a batch the same length by padding with zeros
    batch = [item.t() for item in batch]
    batch = torch.nn.utils.rnn.pad_sequence(batch, batch_first=True, padding_value=0.)
    return batch.permute(0, 2, 1)


def collate_fn(batch):

    # A data tuple has the form:
    # waveform, sample_rate, label, speaker_id, utterance_number

    tensors, targets = [], []

    # Gather in lists, and encode labels as indices
    for waveform, _, label, *_ in batch:
        tensors += [waveform]
        targets += [label_to_index(label)]

    # Group the list of tensors into a batched tensor
    tensors = pad_sequence(tensors)
    targets = torch.stack(targets)

    return tensors, targets


batch_size = 50

if device == "cuda":
    num_workers = 1
    pin_memory = True
else:
    num_workers = 0
    pin_memory = False

train_loader = torch.utils.data.DataLoader(
    train_set,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory,
)

val_loader = torch.utils.data.DataLoader(
    val_set,
    batch_size=batch_size,
    shuffle=True,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory
)

test_loader = torch.utils.data.DataLoader(
    test_set,
    batch_size=batch_size,
    shuffle=False,
    drop_last=False,
    collate_fn=collate_fn,
    num_workers=num_workers,
    pin_memory=pin_memory,
)

# %% [markdown]
# # GRU-2 Model

# %%
class GRU_2(nn.Module):
    def __init__(self, n_input=1, n_output=35, stride=3, hidden_dim=128, n_channel=128, nhead=4, num_layer=4):
        super().__init__()
        self.conv1 = nn.Conv1d(n_input, n_channel, kernel_size=80, stride=stride)
        self.bn1 = nn.BatchNorm1d(n_channel)
        self.pool1 = nn.MaxPool1d(4)
        self.conv2 = nn.Conv1d(n_channel, n_channel, kernel_size=3)
        self.bn2 = nn.BatchNorm1d(n_channel)
        self.pool2 = nn.MaxPool1d(4)
        self.conv3 = nn.Conv1d(n_channel, 2 * n_channel, kernel_size=3)
        self.bn3 = nn.BatchNorm1d(2 * n_channel)
        self.pool3 = nn.MaxPool1d(4)
        self.conv4 = nn.Conv1d(2 * n_channel, 2 * n_channel, kernel_size=3)
        self.bn4 = nn.BatchNorm1d(2 * n_channel)
        self.pool4 = nn.MaxPool1d(4)
        self.GRU = nn.GRU(2 * n_channel, hidden_dim, batch_first=True)
        self.fc1 = nn.Linear(hidden_dim, n_output)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(self.bn1(x))
        x = self.pool1(x)
        x = self.conv2(x)
        x = F.relu(self.bn2(x))
        x = self.pool2(x)
        x = self.conv3(x)
        x = F.relu(self.bn3(x))
        x = self.pool3(x)
        x = self.conv4(x)
        x = F.relu(self.bn4(x))
        x = self.pool4(x)
        x = x.permute(0, 2, 1)
        x, hnn = self.GRU(x)
        x = self.fc1(hnn[-1])
        return F.log_softmax(x, dim=-1)

model = GRU_2(n_input=waveform.shape[0], n_output=len(labels))
model.cuda()

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

n = count_parameters(model)
print("Number of parameters: %s" % n)
# Out:
# Number of parameters: 509347

# %% [markdown]
# # Training and testing
# In this case we use SGD optimizer without weight decay and Negative Log Likelihood as loss function.

# %%
lr = 0.01

# %%
optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=0.0001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.1)  # reduce the learning after 20 epochs by a factor of 10

# %%
def train(epoch, log_interval):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):

        data = data.cuda()
        target = target.cuda()

        output = model(data)

        # negative log-likelihood for a tensor of size (batch x 1 x n_output)
        loss = F.nll_loss(output.squeeze(), target)


        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # print training stats
        if batch_idx % log_interval == 0:
            print(f"Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item():.6f}")

        # record loss
        losses.append(loss.item())

# %%
def number_of_correct(pred, target):
    # count number of correct predictions
    return pred.squeeze().eq(target).sum().item()


def get_likely_index(tensor):
    # find most likely label index for each element in the batch
    return tensor.argmax(dim=-1)


@torch.no_grad()
def evaluate(data_source):
    model.eval()
    total_loss = 0.
    correct = 0
    n = 0
    for data, target in data_source:

        data = data.to(device)
        target = target.to(device)

        output = model(data)

        total_loss += target.numel() * F.nll_loss(output.squeeze(), target).item()
        n += target.numel()

        pred = get_likely_index(output)
        correct += number_of_correct(pred, target)
    
 
    accuracy = 100 * correct / len(test_loader.dataset)
    
    return total_loss / n, accuracy

# %%
best_val_loss = float("inf")
losses = []

log_interval = 100
n_epoch = 40

for epoch in range(1, n_epoch + 1):
    train(epoch, log_interval)
    val_loss, val_acc = evaluate(val_loader)

    print(f'| Validation | val loss {val_loss:5.2f} | val accuracy {val_acc:.0f}%')

    if val_loss < best_val_loss:
      with open("GRU-2_16kHz.pth", 'wb') as f:
        torch.save(model, f)
      best_val_loss = val_loss
    scheduler.step()

with open("GRU-2_16kHz.pth", 'rb') as f:
  model = torch.load(f)

with torch.no_grad():
  test_loss, test_acc = evaluate(test_loader)

print('=' * 89)
print(f'| End of training | test loss {test_loss:5.2f} | test accuracy {test_acc:.0f}%')
print('=' * 89)

# Let's plot the training loss versus the number of iteration.
plt.plot(losses)
plt.title("training loss")
# Out:
# Train Epoch: 1 [0/84843 (0%)]	Loss: 3.606762
# Train Epoch: 1 [5000/84843 (6%)]	Loss: 3.519780
# Train Epoch: 1 [10000/84843 (12%)]	Loss: 3.479803
# Train Epoch: 1 [15000/84843 (18%)]	Loss: 3.490979
# Train Epoch: 1 [20000/84843 (24%)]	Loss: 3.436223
# Train Epoch: 1 [25000/84843 (29%)]	Loss: 3.532172
# Train Epoch: 1 [30000/84843 (35%)]	Loss: 3.437851
# Train Epoch: 1 [35000/84843 (41%)]	Loss: 3.463453
# Train Epoch: 1 [40000/84843 (47%)]	Loss: 3.354149
# Train Epoch: 1 [45000/84843 (53%)]	Loss: 3.458440
# Train Epoch: 1 [50000/84843 (59%)]	Loss: 3.352490
# Train Epoch: 1 [55000/84843 (65%)]	Loss: 3.421511
# Train Epoch: 1 [60000/84843 (71%)]	Loss: 3.417884
# Train Epoch: 1 [65000/84843 (77%)]	Loss: 3.513833
# Train Epoch: 1 [70000/84843 (82%)]	Loss: 3.229798
# Train Epoch: 1 [75000/84843 (88%)]	Loss: 3.281677
# Train Epoch: 1 [80000/84843 (94%)]	Loss: 3.249646
# | Validation | val loss  3.16 | val accuracy 12%
# Train Epoch: 2 [0/84843 (0%)]	Loss: 3.191556
# Train Epoch: 2 [5000/84843 (6%)]	Loss: 3.126671
# Train Epoch: 2 [10000/84843 (12%)]	Loss: 3.139799
# Train Epoch: 2 [15000/84843 (18%)]	Loss: 2.999080
# Train Epoch: 2 [20000/84843 (24%)]	Loss: 2.978799
# Train Epoch: 2 [25000/84843 (29%)]	Loss: 2.869715
# Train Epoch: 2 [30000/84843 (35%)]	Loss: 3.128397
# Train Epoch: 2 [35000/84843 (41%)]	Loss: 2.773050
# Train Epoch: 2 [40000/84843 (47%)]	Loss: 2.843624
# Train Epoch: 2 [45000/84843 (53%)]	Loss: 3.019789
# Train Epoch: 2 [50000/84843 (59%)]	Loss: 2.881747
# Train Epoch: 2 [55000/84843 (65%)]	Loss: 2.624236
# Train Epoch: 2 [60000/84843 (71%)]	Loss: 2.682772
# Train Epoch: 2 [65000/84843 (77%)]	Loss: 2.412651
# Train Epoch: 2 [70000/84843 (82%)]	Loss: 2.376735
# Train Epoch: 2 [75000/84843 (88%)]	Loss: 2.486832
# Train Epoch: 2 [80000/84843 (94%)]	Loss: 2.372602
# | Validation | val loss  2.39 | val accuracy 30%
# Train Epoch: 3 [0/84843 (0%)]	Loss: 2.339687
# Train Epoch: 3 [5000/84843 (6%)]	Loss: 2.465641
# Train Epoch: 3 [10000/84843 (12%)]	Loss: 2.215264
# Train Epoch: 3 [15000/84843 (18%)]	Loss: 2.320472
# Train Epoch: 3 [20000/84843 (24%)]	Loss: 2.216204
# Train Epoch: 3 [25000/84843 (29%)]	Loss: 2.318783
# Train Epoch: 3 [30000/84843 (35%)]	Loss: 2.202107
# Train Epoch: 3 [35000/84843 (41%)]	Loss: 1.896052
# Train Epoch: 3 [40000/84843 (47%)]	Loss: 2.213074
# Train Epoch: 3 [45000/84843 (53%)]	Loss: 1.907992
# Train Epoch: 3 [50000/84843 (59%)]	Loss: 1.826170
# Train Epoch: 3 [55000/84843 (65%)]	Loss: 2.081078
# Train Epoch: 3 [60000/84843 (71%)]	Loss: 2.182008
# Train Epoch: 3 [65000/84843 (77%)]	Loss: 2.170691
# Train Epoch: 3 [70000/84843 (82%)]	Loss: 1.876533
# Train Epoch: 3 [75000/84843 (88%)]	Loss: 1.808109
# Train Epoch: 3 [80000/84843 (94%)]	Loss: 1.563793
# | Validation | val loss  1.87 | val accuracy 43%
# Train Epoch: 4 [0/84843 (0%)]	Loss: 2.161856
# Train Epoch: 4 [5000/84843 (6%)]	Loss: 1.852837
# Train Epoch: 4 [10000/84843 (12%)]	Loss: 1.410153
# Train Epoch: 4 [15000/84843 (18%)]	Loss: 1.788954
# Train Epoch: 4 [20000/84843 (24%)]	Loss: 1.667877
# Train Epoch: 4 [25000/84843 (29%)]	Loss: 1.554095
# Train Epoch: 4 [30000/84843 (35%)]	Loss: 1.535655
# Train Epoch: 4 [35000/84843 (41%)]	Loss: 1.443151
# Train Epoch: 4 [40000/84843 (47%)]	Loss: 1.561527
# Train Epoch: 4 [45000/84843 (53%)]	Loss: 1.403712
# Train Epoch: 4 [50000/84843 (59%)]	Loss: 1.402445
# Train Epoch: 4 [55000/84843 (65%)]	Loss: 1.019668
# Train Epoch: 4 [60000/84843 (71%)]	Loss: 1.357010
# Train Epoch: 4 [65000/84843 (77%)]	Loss: 1.296240
# Train Epoch: 4 [70000/84843 (82%)]	Loss: 1.286611
# Train Epoch: 4 [75000/84843 (88%)]	Loss: 1.098798
# Train Epoch: 4 [80000/84843 (94%)]	Loss: 1.370428
# | Validation | val loss  1.17 | val accuracy 62%
# Train Epoch: 5 [0/84843 (0%)]	Loss: 1.092106
# Train Epoch: 5 [5000/84843 (6%)]	Loss: 1.184335
# Train Epoch: 5 [10000/84843 (12%)]	Loss: 1.135843
# Train Epoch: 5 [15000/84843 (18%)]	Loss: 1.165415
# Train Epoch: 5 [20000/84843 (24%)]	Loss: 1.130487
# Train Epoch: 5 [25000/84843 (29%)]	Loss: 1.190732
# Train Epoch: 5 [30000/84843 (35%)]	Loss: 1.026621
# Train Epoch: 5 [35000/84843 (41%)]	Loss: 0.980732
# Train Epoch: 5 [40000/84843 (47%)]	Loss: 0.995985
# Train Epoch: 5 [45000/84843 (53%)]	Loss: 1.010298
# Train Epoch: 5 [50000/84843 (59%)]	Loss: 0.995371
# Train Epoch: 5 [55000/84843 (65%)]	Loss: 0.960911
# Train Epoch: 5 [60000/84843 (71%)]	Loss: 1.027915
# Train Epoch: 5 [65000/84843 (77%)]	Loss: 0.972054
# Train Epoch: 5 [70000/84843 (82%)]	Loss: 1.020713
# Train Epoch: 5 [75000/84843 (88%)]	Loss: 0.938321
# Train Epoch: 5 [80000/84843 (94%)]	Loss: 0.886641
# | Validation | val loss  0.94 | val accuracy 67%
# Train Epoch: 6 [0/84843 (0%)]	Loss: 0.904252
# Train Epoch: 6 [5000/84843 (6%)]	Loss: 0.925739
# Train Epoch: 6 [10000/84843 (12%)]	Loss: 1.148046
# Train Epoch: 6 [15000/84843 (18%)]	Loss: 0.997818
# Train Epoch: 6 [20000/84843 (24%)]	Loss: 0.926819
# Train Epoch: 6 [25000/84843 (29%)]	Loss: 0.802696
# Train Epoch: 6 [30000/84843 (35%)]	Loss: 1.028867
# Train Epoch: 6 [35000/84843 (41%)]	Loss: 0.887248
# Train Epoch: 6 [40000/84843 (47%)]	Loss: 0.791876
# Train Epoch: 6 [45000/84843 (53%)]	Loss: 1.177262
# Train Epoch: 6 [50000/84843 (59%)]	Loss: 1.049694
# Train Epoch: 6 [55000/84843 (65%)]	Loss: 0.729360
# Train Epoch: 6 [60000/84843 (71%)]	Loss: 0.977173
# Train Epoch: 6 [65000/84843 (77%)]	Loss: 1.047394
# Train Epoch: 6 [70000/84843 (82%)]	Loss: 0.574741
# Train Epoch: 6 [75000/84843 (88%)]	Loss: 0.519617
# Train Epoch: 6 [80000/84843 (94%)]	Loss: 0.875684
# | Validation | val loss  0.77 | val accuracy 71%
# Train Epoch: 7 [0/84843 (0%)]	Loss: 0.796952
# Train Epoch: 7 [5000/84843 (6%)]	Loss: 0.716129
# Train Epoch: 7 [10000/84843 (12%)]	Loss: 0.683876
# Train Epoch: 7 [15000/84843 (18%)]	Loss: 0.686031
# Train Epoch: 7 [20000/84843 (24%)]	Loss: 0.815547
# Train Epoch: 7 [25000/84843 (29%)]	Loss: 0.796252
# Train Epoch: 7 [30000/84843 (35%)]	Loss: 0.715852
# Train Epoch: 7 [35000/84843 (41%)]	Loss: 1.052541
# Train Epoch: 7 [40000/84843 (47%)]	Loss: 0.672081
# Train Epoch: 7 [45000/84843 (53%)]	Loss: 0.870917
# Train Epoch: 7 [50000/84843 (59%)]	Loss: 0.611623
# Train Epoch: 7 [55000/84843 (65%)]	Loss: 0.465519
# Train Epoch: 7 [60000/84843 (71%)]	Loss: 0.887014
# Train Epoch: 7 [65000/84843 (77%)]	Loss: 0.741516
# Train Epoch: 7 [70000/84843 (82%)]	Loss: 0.672805
# Train Epoch: 7 [75000/84843 (88%)]	Loss: 0.744258
# Train Epoch: 7 [80000/84843 (94%)]	Loss: 0.732579
# | Validation | val loss  0.64 | val accuracy 74%
# Train Epoch: 8 [0/84843 (0%)]	Loss: 0.428247
# Train Epoch: 8 [5000/84843 (6%)]	Loss: 0.541280
# Train Epoch: 8 [10000/84843 (12%)]	Loss: 0.604766
# Train Epoch: 8 [15000/84843 (18%)]	Loss: 0.836949
# Train Epoch: 8 [20000/84843 (24%)]	Loss: 0.768632
# Train Epoch: 8 [25000/84843 (29%)]	Loss: 0.625489
# Train Epoch: 8 [30000/84843 (35%)]	Loss: 0.905291
# Train Epoch: 8 [35000/84843 (41%)]	Loss: 0.752080
# Train Epoch: 8 [40000/84843 (47%)]	Loss: 0.818101
# Train Epoch: 8 [45000/84843 (53%)]	Loss: 0.754581
# Train Epoch: 8 [50000/84843 (59%)]	Loss: 0.497725
# Train Epoch: 8 [55000/84843 (65%)]	Loss: 0.682417
# Train Epoch: 8 [60000/84843 (71%)]	Loss: 0.514575
# Train Epoch: 8 [65000/84843 (77%)]	Loss: 0.744697
# Train Epoch: 8 [70000/84843 (82%)]	Loss: 0.665971
# Train Epoch: 8 [75000/84843 (88%)]	Loss: 0.408113
# Train Epoch: 8 [80000/84843 (94%)]	Loss: 0.654315
# | Validation | val loss  0.67 | val accuracy 74%
# Train Epoch: 9 [0/84843 (0%)]	Loss: 0.731059
# Train Epoch: 9 [5000/84843 (6%)]	Loss: 0.625954
# Train Epoch: 9 [10000/84843 (12%)]	Loss: 0.655117
# Train Epoch: 9 [15000/84843 (18%)]	Loss: 0.485243
# Train Epoch: 9 [20000/84843 (24%)]	Loss: 0.571817
# Train Epoch: 9 [25000/84843 (29%)]	Loss: 0.604504
# Train Epoch: 9 [30000/84843 (35%)]	Loss: 0.801885
# Train Epoch: 9 [35000/84843 (41%)]	Loss: 0.648893
# Train Epoch: 9 [40000/84843 (47%)]	Loss: 0.491505
# Train Epoch: 9 [45000/84843 (53%)]	Loss: 0.287105
# Train Epoch: 9 [50000/84843 (59%)]	Loss: 0.683068
# Train Epoch: 9 [55000/84843 (65%)]	Loss: 0.547678
# Train Epoch: 9 [60000/84843 (71%)]	Loss: 0.496515
# Train Epoch: 9 [65000/84843 (77%)]	Loss: 0.277909
# Train Epoch: 9 [70000/84843 (82%)]	Loss: 0.509551
# Train Epoch: 9 [75000/84843 (88%)]	Loss: 0.717305
# Train Epoch: 9 [80000/84843 (94%)]	Loss: 0.364180
# | Validation | val loss  0.51 | val accuracy 78%
# Train Epoch: 10 [0/84843 (0%)]	Loss: 0.318790
# Train Epoch: 10 [5000/84843 (6%)]	Loss: 0.565291
# Train Epoch: 10 [10000/84843 (12%)]	Loss: 0.482171
# Train Epoch: 10 [15000/84843 (18%)]	Loss: 0.524997
# Train Epoch: 10 [20000/84843 (24%)]	Loss: 0.675622
# Train Epoch: 10 [25000/84843 (29%)]	Loss: 0.532451
# Train Epoch: 10 [30000/84843 (35%)]	Loss: 0.487026
# Train Epoch: 10 [35000/84843 (41%)]	Loss: 0.797909
# Train Epoch: 10 [40000/84843 (47%)]	Loss: 0.541131
# Train Epoch: 10 [45000/84843 (53%)]	Loss: 0.790708
# Train Epoch: 10 [50000/84843 (59%)]	Loss: 0.390966
# Train Epoch: 10 [55000/84843 (65%)]	Loss: 0.514071
# Train Epoch: 10 [60000/84843 (71%)]	Loss: 0.655963
# Train Epoch: 10 [65000/84843 (77%)]	Loss: 0.458294
# Train Epoch: 10 [70000/84843 (82%)]	Loss: 0.480333
# Train Epoch: 10 [75000/84843 (88%)]	Loss: 0.417795
# Train Epoch: 10 [80000/84843 (94%)]	Loss: 0.502166
# | Validation | val loss  0.49 | val accuracy 78%
# Train Epoch: 11 [0/84843 (0%)]	Loss: 0.464679
# Train Epoch: 11 [5000/84843 (6%)]	Loss: 0.703752
# Train Epoch: 11 [10000/84843 (12%)]	Loss: 0.490270
# Train Epoch: 11 [15000/84843 (18%)]	Loss: 0.454207
# Train Epoch: 11 [20000/84843 (24%)]	Loss: 0.471213
# Train Epoch: 11 [25000/84843 (29%)]	Loss: 0.376629
# Train Epoch: 11 [30000/84843 (35%)]	Loss: 0.692198
# Train Epoch: 11 [35000/84843 (41%)]	Loss: 0.315816
# Train Epoch: 11 [40000/84843 (47%)]	Loss: 0.297218
# Train Epoch: 11 [45000/84843 (53%)]	Loss: 0.305421
# Train Epoch: 11 [50000/84843 (59%)]	Loss: 0.673266
# Train Epoch: 11 [55000/84843 (65%)]	Loss: 0.460965
# Train Epoch: 11 [60000/84843 (71%)]	Loss: 0.510496
# Train Epoch: 11 [65000/84843 (77%)]	Loss: 0.364842
# Train Epoch: 11 [70000/84843 (82%)]	Loss: 0.535527
# Train Epoch: 11 [75000/84843 (88%)]	Loss: 0.381945
# Train Epoch: 11 [80000/84843 (94%)]	Loss: 0.705320
# | Validation | val loss  0.45 | val accuracy 79%
# Train Epoch: 12 [0/84843 (0%)]	Loss: 0.483411
# Train Epoch: 12 [5000/84843 (6%)]	Loss: 0.522243
# Train Epoch: 12 [10000/84843 (12%)]	Loss: 0.564207
# Train Epoch: 12 [15000/84843 (18%)]	Loss: 0.373815
# Train Epoch: 12 [20000/84843 (24%)]	Loss: 0.436507
# Train Epoch: 12 [25000/84843 (29%)]	Loss: 0.365239
# Train Epoch: 12 [30000/84843 (35%)]	Loss: 0.489028
# Train Epoch: 12 [35000/84843 (41%)]	Loss: 0.506386
# Train Epoch: 12 [40000/84843 (47%)]	Loss: 0.655606
# Train Epoch: 12 [45000/84843 (53%)]	Loss: 0.523780
# Train Epoch: 12 [50000/84843 (59%)]	Loss: 0.280529
# Train Epoch: 12 [55000/84843 (65%)]	Loss: 0.387541
# Train Epoch: 12 [60000/84843 (71%)]	Loss: 0.255021
# Train Epoch: 12 [65000/84843 (77%)]	Loss: 0.386792
# Train Epoch: 12 [70000/84843 (82%)]	Loss: 0.602305
# Train Epoch: 12 [75000/84843 (88%)]	Loss: 0.505978
# Train Epoch: 12 [80000/84843 (94%)]	Loss: 0.463944
# | Validation | val loss  0.43 | val accuracy 79%
# Train Epoch: 13 [0/84843 (0%)]	Loss: 0.287103
# Train Epoch: 13 [5000/84843 (6%)]	Loss: 0.494486
# Train Epoch: 13 [10000/84843 (12%)]	Loss: 0.441786
# Train Epoch: 13 [15000/84843 (18%)]	Loss: 0.582911
# Train Epoch: 13 [20000/84843 (24%)]	Loss: 0.572037
# Train Epoch: 13 [25000/84843 (29%)]	Loss: 0.339348
# Train Epoch: 13 [30000/84843 (35%)]	Loss: 0.231118
# Train Epoch: 13 [35000/84843 (41%)]	Loss: 0.572936
# Train Epoch: 13 [40000/84843 (47%)]	Loss: 0.331660
# Train Epoch: 13 [45000/84843 (53%)]	Loss: 0.151000
# Train Epoch: 13 [50000/84843 (59%)]	Loss: 0.447353
# Train Epoch: 13 [55000/84843 (65%)]	Loss: 0.414788
# Train Epoch: 13 [60000/84843 (71%)]	Loss: 0.333373
# Train Epoch: 13 [65000/84843 (77%)]	Loss: 0.229736
# Train Epoch: 13 [70000/84843 (82%)]	Loss: 0.546794
# Train Epoch: 13 [75000/84843 (88%)]	Loss: 0.418844
# Train Epoch: 13 [80000/84843 (94%)]	Loss: 0.355834
# | Validation | val loss  0.40 | val accuracy 80%
# Train Epoch: 14 [0/84843 (0%)]	Loss: 0.443385
# Train Epoch: 14 [5000/84843 (6%)]	Loss: 0.356719
# Train Epoch: 14 [10000/84843 (12%)]	Loss: 0.232612
# Train Epoch: 14 [15000/84843 (18%)]	Loss: 0.200920
# Train Epoch: 14 [20000/84843 (24%)]	Loss: 0.632133
# Train Epoch: 14 [25000/84843 (29%)]	Loss: 0.404294
# Train Epoch: 14 [30000/84843 (35%)]	Loss: 0.523052
# Train Epoch: 14 [35000/84843 (41%)]	Loss: 0.511405
# Train Epoch: 14 [40000/84843 (47%)]	Loss: 0.386431
# Train Epoch: 14 [45000/84843 (53%)]	Loss: 0.595338
# Train Epoch: 14 [50000/84843 (59%)]	Loss: 0.297206
# Train Epoch: 14 [55000/84843 (65%)]	Loss: 0.318037
# Train Epoch: 14 [60000/84843 (71%)]	Loss: 0.295728
# Train Epoch: 14 [65000/84843 (77%)]	Loss: 0.530369
# Train Epoch: 14 [70000/84843 (82%)]	Loss: 0.153330
# Train Epoch: 14 [75000/84843 (88%)]	Loss: 0.355212
# Train Epoch: 14 [80000/84843 (94%)]	Loss: 0.310730
# | Validation | val loss  0.38 | val accuracy 81%
# Train Epoch: 15 [0/84843 (0%)]	Loss: 0.297047
# Train Epoch: 15 [5000/84843 (6%)]	Loss: 0.342044
# Train Epoch: 15 [10000/84843 (12%)]	Loss: 0.161612
# Train Epoch: 15 [15000/84843 (18%)]	Loss: 0.304473
# Train Epoch: 15 [20000/84843 (24%)]	Loss: 0.447021
# Train Epoch: 15 [25000/84843 (29%)]	Loss: 0.260492
# Train Epoch: 15 [30000/84843 (35%)]	Loss: 0.393252
# Train Epoch: 15 [35000/84843 (41%)]	Loss: 0.459323
# Train Epoch: 15 [40000/84843 (47%)]	Loss: 0.379310
# Train Epoch: 15 [45000/84843 (53%)]	Loss: 0.422090
# Train Epoch: 15 [50000/84843 (59%)]	Loss: 0.407042
# Train Epoch: 15 [55000/84843 (65%)]	Loss: 0.278562
# Train Epoch: 15 [60000/84843 (71%)]	Loss: 0.218567
# Train Epoch: 15 [65000/84843 (77%)]	Loss: 0.151466
# Train Epoch: 15 [70000/84843 (82%)]	Loss: 0.290012
# Train Epoch: 15 [75000/84843 (88%)]	Loss: 0.474331
# Train Epoch: 15 [80000/84843 (94%)]	Loss: 0.263826
# | Validation | val loss  0.37 | val accuracy 81%
# Train Epoch: 16 [0/84843 (0%)]	Loss: 0.352026
# Train Epoch: 16 [5000/84843 (6%)]	Loss: 0.373886
# Train Epoch: 16 [10000/84843 (12%)]	Loss: 0.419459
# Train Epoch: 16 [15000/84843 (18%)]	Loss: 0.420672
# Train Epoch: 16 [20000/84843 (24%)]	Loss: 0.235044
# Train Epoch: 16 [25000/84843 (29%)]	Loss: 0.505666
# Train Epoch: 16 [30000/84843 (35%)]	Loss: 0.555448
# Train Epoch: 16 [35000/84843 (41%)]	Loss: 0.380754
# Train Epoch: 16 [40000/84843 (47%)]	Loss: 0.480039
# Train Epoch: 16 [45000/84843 (53%)]	Loss: 0.473835
# Train Epoch: 16 [50000/84843 (59%)]	Loss: 0.222100
# Train Epoch: 16 [55000/84843 (65%)]	Loss: 0.324825
# Train Epoch: 16 [60000/84843 (71%)]	Loss: 0.332247
# Train Epoch: 16 [65000/84843 (77%)]	Loss: 0.289698
# Train Epoch: 16 [70000/84843 (82%)]	Loss: 0.291515
# Train Epoch: 16 [75000/84843 (88%)]	Loss: 0.156346
# Train Epoch: 16 [80000/84843 (94%)]	Loss: 0.309515
# | Validation | val loss  0.36 | val accuracy 81%
# Train Epoch: 17 [0/84843 (0%)]	Loss: 0.292814
# Train Epoch: 17 [5000/84843 (6%)]	Loss: 0.378656
# Train Epoch: 17 [10000/84843 (12%)]	Loss: 0.410545
# Train Epoch: 17 [15000/84843 (18%)]	Loss: 0.271858
# Train Epoch: 17 [20000/84843 (24%)]	Loss: 0.249666
# Train Epoch: 17 [25000/84843 (29%)]	Loss: 0.434735
# Train Epoch: 17 [30000/84843 (35%)]	Loss: 0.226290
# Train Epoch: 17 [35000/84843 (41%)]	Loss: 0.355745
# Train Epoch: 17 [40000/84843 (47%)]	Loss: 0.337099
# Train Epoch: 17 [45000/84843 (53%)]	Loss: 0.427339
# Train Epoch: 17 [50000/84843 (59%)]	Loss: 0.465563
# Train Epoch: 17 [55000/84843 (65%)]	Loss: 0.363449
# Train Epoch: 17 [60000/84843 (71%)]	Loss: 0.336068
# Train Epoch: 17 [65000/84843 (77%)]	Loss: 0.321541
# Train Epoch: 17 [70000/84843 (82%)]	Loss: 0.322696
# Train Epoch: 17 [75000/84843 (88%)]	Loss: 0.492322
# Train Epoch: 17 [80000/84843 (94%)]	Loss: 0.246149
# | Validation | val loss  0.35 | val accuracy 82%
# Train Epoch: 18 [0/84843 (0%)]	Loss: 0.428481
# Train Epoch: 18 [5000/84843 (6%)]	Loss: 0.127017
# Train Epoch: 18 [10000/84843 (12%)]	Loss: 0.232943
# Train Epoch: 18 [15000/84843 (18%)]	Loss: 0.198958
# Train Epoch: 18 [20000/84843 (24%)]	Loss: 0.470399
# Train Epoch: 18 [25000/84843 (29%)]	Loss: 0.123678
# Train Epoch: 18 [30000/84843 (35%)]	Loss: 0.440236
# Train Epoch: 18 [35000/84843 (41%)]	Loss: 0.382049
# Train Epoch: 18 [40000/84843 (47%)]	Loss: 0.575619
# Train Epoch: 18 [45000/84843 (53%)]	Loss: 0.332560
# Train Epoch: 18 [50000/84843 (59%)]	Loss: 0.216978
# Train Epoch: 18 [55000/84843 (65%)]	Loss: 0.277238
# Train Epoch: 18 [60000/84843 (71%)]	Loss: 0.554538
# Train Epoch: 18 [65000/84843 (77%)]	Loss: 0.300125
# Train Epoch: 18 [70000/84843 (82%)]	Loss: 0.275872
# Train Epoch: 18 [75000/84843 (88%)]	Loss: 0.182301
# Train Epoch: 18 [80000/84843 (94%)]	Loss: 0.256406
# | Validation | val loss  0.34 | val accuracy 82%
# Train Epoch: 19 [0/84843 (0%)]	Loss: 0.174502
# Train Epoch: 19 [5000/84843 (6%)]	Loss: 0.373162
# Train Epoch: 19 [10000/84843 (12%)]	Loss: 0.381399
# Train Epoch: 19 [15000/84843 (18%)]	Loss: 0.364362
# Train Epoch: 19 [20000/84843 (24%)]	Loss: 0.248440
# Train Epoch: 19 [25000/84843 (29%)]	Loss: 0.231364
# Train Epoch: 19 [30000/84843 (35%)]	Loss: 0.214918
# Train Epoch: 19 [35000/84843 (41%)]	Loss: 0.281237
# Train Epoch: 19 [40000/84843 (47%)]	Loss: 0.435792
# Train Epoch: 19 [45000/84843 (53%)]	Loss: 0.355891
# Train Epoch: 19 [50000/84843 (59%)]	Loss: 0.307221
# Train Epoch: 19 [55000/84843 (65%)]	Loss: 0.260944
# Train Epoch: 19 [60000/84843 (71%)]	Loss: 0.604673
# Train Epoch: 19 [65000/84843 (77%)]	Loss: 0.285090
# Train Epoch: 19 [70000/84843 (82%)]	Loss: 0.290619
# Train Epoch: 19 [75000/84843 (88%)]	Loss: 0.132663
# Train Epoch: 19 [80000/84843 (94%)]	Loss: 0.198838
# | Validation | val loss  0.35 | val accuracy 82%
# Train Epoch: 20 [0/84843 (0%)]	Loss: 0.356086
# Train Epoch: 20 [5000/84843 (6%)]	Loss: 0.279478
# Train Epoch: 20 [10000/84843 (12%)]	Loss: 0.233958
# Train Epoch: 20 [15000/84843 (18%)]	Loss: 0.495794
# Train Epoch: 20 [20000/84843 (24%)]	Loss: 0.420101
# Train Epoch: 20 [25000/84843 (29%)]	Loss: 0.123426
# Train Epoch: 20 [30000/84843 (35%)]	Loss: 0.199101
# Train Epoch: 20 [35000/84843 (41%)]	Loss: 0.202725
# Train Epoch: 20 [40000/84843 (47%)]	Loss: 0.255293
# Train Epoch: 20 [45000/84843 (53%)]	Loss: 0.164936
# Train Epoch: 20 [50000/84843 (59%)]	Loss: 0.237619
# Train Epoch: 20 [55000/84843 (65%)]	Loss: 0.233594
# Train Epoch: 20 [60000/84843 (71%)]	Loss: 0.495675
# Train Epoch: 20 [65000/84843 (77%)]	Loss: 0.218083
# Train Epoch: 20 [70000/84843 (82%)]	Loss: 0.161898
# Train Epoch: 20 [75000/84843 (88%)]	Loss: 0.115761
# Train Epoch: 20 [80000/84843 (94%)]	Loss: 0.149339
# | Validation | val loss  0.32 | val accuracy 82%
# Train Epoch: 21 [0/84843 (0%)]	Loss: 0.190801
# Train Epoch: 21 [5000/84843 (6%)]	Loss: 0.102944
# Train Epoch: 21 [10000/84843 (12%)]	Loss: 0.329241
# Train Epoch: 21 [15000/84843 (18%)]	Loss: 0.267285
# Train Epoch: 21 [20000/84843 (24%)]	Loss: 0.395075
# Train Epoch: 21 [25000/84843 (29%)]	Loss: 0.267534
# Train Epoch: 21 [30000/84843 (35%)]	Loss: 0.371761
# Train Epoch: 21 [35000/84843 (41%)]	Loss: 0.354750
# Train Epoch: 21 [40000/84843 (47%)]	Loss: 0.242854
# Train Epoch: 21 [45000/84843 (53%)]	Loss: 0.080629
# Train Epoch: 21 [50000/84843 (59%)]	Loss: 0.229547
# Train Epoch: 21 [55000/84843 (65%)]	Loss: 0.075425
# Train Epoch: 21 [60000/84843 (71%)]	Loss: 0.145208
# Train Epoch: 21 [65000/84843 (77%)]	Loss: 0.262003
# Train Epoch: 21 [70000/84843 (82%)]	Loss: 0.211892
# Train Epoch: 21 [75000/84843 (88%)]	Loss: 0.231198
# Train Epoch: 21 [80000/84843 (94%)]	Loss: 0.158046
# | Validation | val loss  0.30 | val accuracy 83%
# Train Epoch: 22 [0/84843 (0%)]	Loss: 0.163749
# Train Epoch: 22 [5000/84843 (6%)]	Loss: 0.240548
# Train Epoch: 22 [10000/84843 (12%)]	Loss: 0.276779
# Train Epoch: 22 [15000/84843 (18%)]	Loss: 0.364090
# Train Epoch: 22 [20000/84843 (24%)]	Loss: 0.162180
# Train Epoch: 22 [25000/84843 (29%)]	Loss: 0.156641
# Train Epoch: 22 [30000/84843 (35%)]	Loss: 0.220925
# Train Epoch: 22 [35000/84843 (41%)]	Loss: 0.068136
# Train Epoch: 22 [40000/84843 (47%)]	Loss: 0.229754
# Train Epoch: 22 [45000/84843 (53%)]	Loss: 0.176481
# Train Epoch: 22 [50000/84843 (59%)]	Loss: 0.175556
# Train Epoch: 22 [55000/84843 (65%)]	Loss: 0.308453
# Train Epoch: 22 [60000/84843 (71%)]	Loss: 0.289794
# Train Epoch: 22 [65000/84843 (77%)]	Loss: 0.134223
# Train Epoch: 22 [70000/84843 (82%)]	Loss: 0.163407
# Train Epoch: 22 [75000/84843 (88%)]	Loss: 0.395876
# Train Epoch: 22 [80000/84843 (94%)]	Loss: 0.328998
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 23 [0/84843 (0%)]	Loss: 0.176913
# Train Epoch: 23 [5000/84843 (6%)]	Loss: 0.106295
# Train Epoch: 23 [10000/84843 (12%)]	Loss: 0.250413
# Train Epoch: 23 [15000/84843 (18%)]	Loss: 0.204701
# Train Epoch: 23 [20000/84843 (24%)]	Loss: 0.288634
# Train Epoch: 23 [25000/84843 (29%)]	Loss: 0.131007
# Train Epoch: 23 [30000/84843 (35%)]	Loss: 0.172782
# Train Epoch: 23 [35000/84843 (41%)]	Loss: 0.133884
# Train Epoch: 23 [40000/84843 (47%)]	Loss: 0.106163
# Train Epoch: 23 [45000/84843 (53%)]	Loss: 0.152321
# Train Epoch: 23 [50000/84843 (59%)]	Loss: 0.172313
# Train Epoch: 23 [55000/84843 (65%)]	Loss: 0.273581
# Train Epoch: 23 [60000/84843 (71%)]	Loss: 0.207288
# Train Epoch: 23 [65000/84843 (77%)]	Loss: 0.373181
# Train Epoch: 23 [70000/84843 (82%)]	Loss: 0.217764
# Train Epoch: 23 [75000/84843 (88%)]	Loss: 0.087246
# Train Epoch: 23 [80000/84843 (94%)]	Loss: 0.307735
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 24 [0/84843 (0%)]	Loss: 0.203437
# Train Epoch: 24 [5000/84843 (6%)]	Loss: 0.234282
# Train Epoch: 24 [10000/84843 (12%)]	Loss: 0.121996
# Train Epoch: 24 [15000/84843 (18%)]	Loss: 0.131974
# Train Epoch: 24 [20000/84843 (24%)]	Loss: 0.269306
# Train Epoch: 24 [25000/84843 (29%)]	Loss: 0.234186
# Train Epoch: 24 [30000/84843 (35%)]	Loss: 0.120948
# Train Epoch: 24 [35000/84843 (41%)]	Loss: 0.217854
# Train Epoch: 24 [40000/84843 (47%)]	Loss: 0.145568
# Train Epoch: 24 [45000/84843 (53%)]	Loss: 0.201697
# Train Epoch: 24 [50000/84843 (59%)]	Loss: 0.138283
# Train Epoch: 24 [55000/84843 (65%)]	Loss: 0.214658
# Train Epoch: 24 [60000/84843 (71%)]	Loss: 0.202178
# Train Epoch: 24 [65000/84843 (77%)]	Loss: 0.074391
# Train Epoch: 24 [70000/84843 (82%)]	Loss: 0.217454
# Train Epoch: 24 [75000/84843 (88%)]	Loss: 0.184167
# Train Epoch: 24 [80000/84843 (94%)]	Loss: 0.416578
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 25 [0/84843 (0%)]	Loss: 0.198855
# Train Epoch: 25 [5000/84843 (6%)]	Loss: 0.183020
# Train Epoch: 25 [10000/84843 (12%)]	Loss: 0.259676
# Train Epoch: 25 [15000/84843 (18%)]	Loss: 0.130167
# Train Epoch: 25 [20000/84843 (24%)]	Loss: 0.205554
# Train Epoch: 25 [25000/84843 (29%)]	Loss: 0.272416
# Train Epoch: 25 [30000/84843 (35%)]	Loss: 0.299679
# Train Epoch: 25 [35000/84843 (41%)]	Loss: 0.184197
# Train Epoch: 25 [40000/84843 (47%)]	Loss: 0.145561
# Train Epoch: 25 [45000/84843 (53%)]	Loss: 0.116027
# Train Epoch: 25 [50000/84843 (59%)]	Loss: 0.105688
# Train Epoch: 25 [55000/84843 (65%)]	Loss: 0.073866
# Train Epoch: 25 [60000/84843 (71%)]	Loss: 0.037151
# Train Epoch: 25 [65000/84843 (77%)]	Loss: 0.202346
# Train Epoch: 25 [70000/84843 (82%)]	Loss: 0.227485
# Train Epoch: 25 [75000/84843 (88%)]	Loss: 0.187622
# Train Epoch: 25 [80000/84843 (94%)]	Loss: 0.381559
# | Validation | val loss  0.28 | val accuracy 83%
# Train Epoch: 26 [0/84843 (0%)]	Loss: 0.219324
# Train Epoch: 26 [5000/84843 (6%)]	Loss: 0.368620
# Train Epoch: 26 [10000/84843 (12%)]	Loss: 0.226721
# Train Epoch: 26 [15000/84843 (18%)]	Loss: 0.177359
# Train Epoch: 26 [20000/84843 (24%)]	Loss: 0.210384
# Train Epoch: 26 [25000/84843 (29%)]	Loss: 0.230479
# Train Epoch: 26 [30000/84843 (35%)]	Loss: 0.208896
# Train Epoch: 26 [35000/84843 (41%)]	Loss: 0.116410
# Train Epoch: 26 [40000/84843 (47%)]	Loss: 0.126868
# Train Epoch: 26 [45000/84843 (53%)]	Loss: 0.174048
# Train Epoch: 26 [50000/84843 (59%)]	Loss: 0.239903
# Train Epoch: 26 [55000/84843 (65%)]	Loss: 0.114352
# Train Epoch: 26 [60000/84843 (71%)]	Loss: 0.141655
# Train Epoch: 26 [65000/84843 (77%)]	Loss: 0.111231
# Train Epoch: 26 [70000/84843 (82%)]	Loss: 0.067854
# Train Epoch: 26 [75000/84843 (88%)]	Loss: 0.228631
# Train Epoch: 26 [80000/84843 (94%)]	Loss: 0.156592
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 27 [0/84843 (0%)]	Loss: 0.300389
# Train Epoch: 27 [5000/84843 (6%)]	Loss: 0.285230
# Train Epoch: 27 [10000/84843 (12%)]	Loss: 0.167005
# Train Epoch: 27 [15000/84843 (18%)]	Loss: 0.191737
# Train Epoch: 27 [20000/84843 (24%)]	Loss: 0.144211
# Train Epoch: 27 [25000/84843 (29%)]	Loss: 0.094417
# Train Epoch: 27 [30000/84843 (35%)]	Loss: 0.151158
# Train Epoch: 27 [35000/84843 (41%)]	Loss: 0.168817
# Train Epoch: 27 [40000/84843 (47%)]	Loss: 0.226032
# Train Epoch: 27 [45000/84843 (53%)]	Loss: 0.281068
# Train Epoch: 27 [50000/84843 (59%)]	Loss: 0.209682
# Train Epoch: 27 [55000/84843 (65%)]	Loss: 0.098207
# Train Epoch: 27 [60000/84843 (71%)]	Loss: 0.333183
# Train Epoch: 27 [65000/84843 (77%)]	Loss: 0.229240
# Train Epoch: 27 [70000/84843 (82%)]	Loss: 0.330249
# Train Epoch: 27 [75000/84843 (88%)]	Loss: 0.296120
# Train Epoch: 27 [80000/84843 (94%)]	Loss: 0.262135
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 28 [0/84843 (0%)]	Loss: 0.157973
# Train Epoch: 28 [5000/84843 (6%)]	Loss: 0.153417
# Train Epoch: 28 [10000/84843 (12%)]	Loss: 0.063953
# Train Epoch: 28 [15000/84843 (18%)]	Loss: 0.344765
# Train Epoch: 28 [20000/84843 (24%)]	Loss: 0.257490
# Train Epoch: 28 [25000/84843 (29%)]	Loss: 0.206930
# Train Epoch: 28 [30000/84843 (35%)]	Loss: 0.051268
# Train Epoch: 28 [35000/84843 (41%)]	Loss: 0.135985
# Train Epoch: 28 [40000/84843 (47%)]	Loss: 0.407501
# Train Epoch: 28 [45000/84843 (53%)]	Loss: 0.042023
# Train Epoch: 28 [50000/84843 (59%)]	Loss: 0.117046
# Train Epoch: 28 [55000/84843 (65%)]	Loss: 0.182180
# Train Epoch: 28 [60000/84843 (71%)]	Loss: 0.075240
# Train Epoch: 28 [65000/84843 (77%)]	Loss: 0.186781
# Train Epoch: 28 [70000/84843 (82%)]	Loss: 0.283495
# Train Epoch: 28 [75000/84843 (88%)]	Loss: 0.132464
# Train Epoch: 28 [80000/84843 (94%)]	Loss: 0.149783
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 29 [0/84843 (0%)]	Loss: 0.318629
# Train Epoch: 29 [5000/84843 (6%)]	Loss: 0.073999
# Train Epoch: 29 [10000/84843 (12%)]	Loss: 0.208833
# Train Epoch: 29 [15000/84843 (18%)]	Loss: 0.148464
# Train Epoch: 29 [20000/84843 (24%)]	Loss: 0.148319
# Train Epoch: 29 [25000/84843 (29%)]	Loss: 0.073616
# Train Epoch: 29 [30000/84843 (35%)]	Loss: 0.410726
# Train Epoch: 29 [35000/84843 (41%)]	Loss: 0.141037
# Train Epoch: 29 [40000/84843 (47%)]	Loss: 0.177672
# Train Epoch: 29 [45000/84843 (53%)]	Loss: 0.109419
# Train Epoch: 29 [50000/84843 (59%)]	Loss: 0.097322
# Train Epoch: 29 [55000/84843 (65%)]	Loss: 0.099344
# Train Epoch: 29 [60000/84843 (71%)]	Loss: 0.071370
# Train Epoch: 29 [65000/84843 (77%)]	Loss: 0.139538
# Train Epoch: 29 [70000/84843 (82%)]	Loss: 0.104292
# Train Epoch: 29 [75000/84843 (88%)]	Loss: 0.186649
# Train Epoch: 29 [80000/84843 (94%)]	Loss: 0.157330
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 30 [0/84843 (0%)]	Loss: 0.382171
# Train Epoch: 30 [5000/84843 (6%)]	Loss: 0.115823
# Train Epoch: 30 [10000/84843 (12%)]	Loss: 0.230048
# Train Epoch: 30 [15000/84843 (18%)]	Loss: 0.097645
# Train Epoch: 30 [20000/84843 (24%)]	Loss: 0.261472
# Train Epoch: 30 [25000/84843 (29%)]	Loss: 0.118205
# Train Epoch: 30 [30000/84843 (35%)]	Loss: 0.291088
# Train Epoch: 30 [35000/84843 (41%)]	Loss: 0.104474
# Train Epoch: 30 [40000/84843 (47%)]	Loss: 0.255059
# Train Epoch: 30 [45000/84843 (53%)]	Loss: 0.211431
# Train Epoch: 30 [50000/84843 (59%)]	Loss: 0.202550
# Train Epoch: 30 [55000/84843 (65%)]	Loss: 0.182916
# Train Epoch: 30 [60000/84843 (71%)]	Loss: 0.143335
# Train Epoch: 30 [65000/84843 (77%)]	Loss: 0.193177
# Train Epoch: 30 [70000/84843 (82%)]	Loss: 0.089785
# Train Epoch: 30 [75000/84843 (88%)]	Loss: 0.134357
# Train Epoch: 30 [80000/84843 (94%)]	Loss: 0.128988
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 31 [0/84843 (0%)]	Loss: 0.089704
# Train Epoch: 31 [5000/84843 (6%)]	Loss: 0.148974
# Train Epoch: 31 [10000/84843 (12%)]	Loss: 0.105696
# Train Epoch: 31 [15000/84843 (18%)]	Loss: 0.213180
# Train Epoch: 31 [20000/84843 (24%)]	Loss: 0.164343
# Train Epoch: 31 [25000/84843 (29%)]	Loss: 0.077047
# Train Epoch: 31 [30000/84843 (35%)]	Loss: 0.132191
# Train Epoch: 31 [35000/84843 (41%)]	Loss: 0.134493
# Train Epoch: 31 [40000/84843 (47%)]	Loss: 0.130878
# Train Epoch: 31 [45000/84843 (53%)]	Loss: 0.080742
# Train Epoch: 31 [50000/84843 (59%)]	Loss: 0.234697
# Train Epoch: 31 [55000/84843 (65%)]	Loss: 0.234873
# Train Epoch: 31 [60000/84843 (71%)]	Loss: 0.255080
# Train Epoch: 31 [65000/84843 (77%)]	Loss: 0.198747
# Train Epoch: 31 [70000/84843 (82%)]	Loss: 0.167042
# Train Epoch: 31 [75000/84843 (88%)]	Loss: 0.215203
# Train Epoch: 31 [80000/84843 (94%)]	Loss: 0.209326
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 32 [0/84843 (0%)]	Loss: 0.070417
# Train Epoch: 32 [5000/84843 (6%)]	Loss: 0.166886
# Train Epoch: 32 [10000/84843 (12%)]	Loss: 0.193796
# Train Epoch: 32 [15000/84843 (18%)]	Loss: 0.072063
# Train Epoch: 32 [20000/84843 (24%)]	Loss: 0.077268
# Train Epoch: 32 [25000/84843 (29%)]	Loss: 0.132655
# Train Epoch: 32 [30000/84843 (35%)]	Loss: 0.078535
# Train Epoch: 32 [35000/84843 (41%)]	Loss: 0.138751
# Train Epoch: 32 [40000/84843 (47%)]	Loss: 0.138657
# Train Epoch: 32 [45000/84843 (53%)]	Loss: 0.064180
# Train Epoch: 32 [50000/84843 (59%)]	Loss: 0.116984
# Train Epoch: 32 [55000/84843 (65%)]	Loss: 0.233913
# Train Epoch: 32 [60000/84843 (71%)]	Loss: 0.463165
# Train Epoch: 32 [65000/84843 (77%)]	Loss: 0.216572
# Train Epoch: 32 [70000/84843 (82%)]	Loss: 0.273747
# Train Epoch: 32 [75000/84843 (88%)]	Loss: 0.174304
# Train Epoch: 32 [80000/84843 (94%)]	Loss: 0.180703
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 33 [0/84843 (0%)]	Loss: 0.211101
# Train Epoch: 33 [5000/84843 (6%)]	Loss: 0.202896
# Train Epoch: 33 [10000/84843 (12%)]	Loss: 0.316807
# Train Epoch: 33 [15000/84843 (18%)]	Loss: 0.100259
# Train Epoch: 33 [20000/84843 (24%)]	Loss: 0.210713
# Train Epoch: 33 [25000/84843 (29%)]	Loss: 0.268755
# Train Epoch: 33 [30000/84843 (35%)]	Loss: 0.160011
# Train Epoch: 33 [35000/84843 (41%)]	Loss: 0.226965
# Train Epoch: 33 [40000/84843 (47%)]	Loss: 0.167533
# Train Epoch: 33 [45000/84843 (53%)]	Loss: 0.112440
# Train Epoch: 33 [50000/84843 (59%)]	Loss: 0.094712
# Train Epoch: 33 [55000/84843 (65%)]	Loss: 0.314789
# Train Epoch: 33 [60000/84843 (71%)]	Loss: 0.214379
# Train Epoch: 33 [65000/84843 (77%)]	Loss: 0.130273
# Train Epoch: 33 [70000/84843 (82%)]	Loss: 0.400233
# Train Epoch: 33 [75000/84843 (88%)]	Loss: 0.114554
# Train Epoch: 33 [80000/84843 (94%)]	Loss: 0.200866
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 34 [0/84843 (0%)]	Loss: 0.225937
# Train Epoch: 34 [5000/84843 (6%)]	Loss: 0.048622
# Train Epoch: 34 [10000/84843 (12%)]	Loss: 0.137897
# Train Epoch: 34 [15000/84843 (18%)]	Loss: 0.131691
# Train Epoch: 34 [20000/84843 (24%)]	Loss: 0.264907
# Train Epoch: 34 [25000/84843 (29%)]	Loss: 0.231421
# Train Epoch: 34 [30000/84843 (35%)]	Loss: 0.150195
# Train Epoch: 34 [35000/84843 (41%)]	Loss: 0.143585
# Train Epoch: 34 [40000/84843 (47%)]	Loss: 0.228358
# Train Epoch: 34 [45000/84843 (53%)]	Loss: 0.124462
# Train Epoch: 34 [50000/84843 (59%)]	Loss: 0.206535
# Train Epoch: 34 [55000/84843 (65%)]	Loss: 0.129246
# Train Epoch: 34 [60000/84843 (71%)]	Loss: 0.260617
# Train Epoch: 34 [65000/84843 (77%)]	Loss: 0.024964
# Train Epoch: 34 [70000/84843 (82%)]	Loss: 0.292811
# Train Epoch: 34 [75000/84843 (88%)]	Loss: 0.257593
# Train Epoch: 34 [80000/84843 (94%)]	Loss: 0.161633
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 35 [0/84843 (0%)]	Loss: 0.142198
# Train Epoch: 35 [5000/84843 (6%)]	Loss: 0.104731
# Train Epoch: 35 [10000/84843 (12%)]	Loss: 0.129580
# Train Epoch: 35 [15000/84843 (18%)]	Loss: 0.099658
# Train Epoch: 35 [20000/84843 (24%)]	Loss: 0.277927
# Train Epoch: 35 [25000/84843 (29%)]	Loss: 0.266356
# Train Epoch: 35 [30000/84843 (35%)]	Loss: 0.117725
# Train Epoch: 35 [35000/84843 (41%)]	Loss: 0.173133
# Train Epoch: 35 [40000/84843 (47%)]	Loss: 0.033472
# Train Epoch: 35 [45000/84843 (53%)]	Loss: 0.116166
# Train Epoch: 35 [50000/84843 (59%)]	Loss: 0.305338
# Train Epoch: 35 [55000/84843 (65%)]	Loss: 0.101902
# Train Epoch: 35 [60000/84843 (71%)]	Loss: 0.155200
# Train Epoch: 35 [65000/84843 (77%)]	Loss: 0.065373
# Train Epoch: 35 [70000/84843 (82%)]	Loss: 0.269777
# Train Epoch: 35 [75000/84843 (88%)]	Loss: 0.143243
# Train Epoch: 35 [80000/84843 (94%)]	Loss: 0.093758
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 36 [0/84843 (0%)]	Loss: 0.332185
# Train Epoch: 36 [5000/84843 (6%)]	Loss: 0.156384
# Train Epoch: 36 [10000/84843 (12%)]	Loss: 0.187500
# Train Epoch: 36 [15000/84843 (18%)]	Loss: 0.173869
# Train Epoch: 36 [20000/84843 (24%)]	Loss: 0.077783
# Train Epoch: 36 [25000/84843 (29%)]	Loss: 0.135220
# Train Epoch: 36 [30000/84843 (35%)]	Loss: 0.092377
# Train Epoch: 36 [35000/84843 (41%)]	Loss: 0.082516
# Train Epoch: 36 [40000/84843 (47%)]	Loss: 0.214820
# Train Epoch: 36 [45000/84843 (53%)]	Loss: 0.161348
# Train Epoch: 36 [50000/84843 (59%)]	Loss: 0.091511
# Train Epoch: 36 [55000/84843 (65%)]	Loss: 0.060972
# Train Epoch: 36 [60000/84843 (71%)]	Loss: 0.288625
# Train Epoch: 36 [65000/84843 (77%)]	Loss: 0.100643
# Train Epoch: 36 [70000/84843 (82%)]	Loss: 0.140414
# Train Epoch: 36 [75000/84843 (88%)]	Loss: 0.230752
# Train Epoch: 36 [80000/84843 (94%)]	Loss: 0.213262
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 37 [0/84843 (0%)]	Loss: 0.160440
# Train Epoch: 37 [5000/84843 (6%)]	Loss: 0.210531
# Train Epoch: 37 [10000/84843 (12%)]	Loss: 0.202212
# Train Epoch: 37 [15000/84843 (18%)]	Loss: 0.202144
# Train Epoch: 37 [20000/84843 (24%)]	Loss: 0.252238
# Train Epoch: 37 [25000/84843 (29%)]	Loss: 0.341925
# Train Epoch: 37 [30000/84843 (35%)]	Loss: 0.086367
# Train Epoch: 37 [35000/84843 (41%)]	Loss: 0.199237
# Train Epoch: 37 [40000/84843 (47%)]	Loss: 0.063229
# Train Epoch: 37 [45000/84843 (53%)]	Loss: 0.391782
# Train Epoch: 37 [50000/84843 (59%)]	Loss: 0.259341
# Train Epoch: 37 [55000/84843 (65%)]	Loss: 0.161232
# Train Epoch: 37 [60000/84843 (71%)]	Loss: 0.243266
# Train Epoch: 37 [65000/84843 (77%)]	Loss: 0.172180
# Train Epoch: 37 [70000/84843 (82%)]	Loss: 0.231554
# Train Epoch: 37 [75000/84843 (88%)]	Loss: 0.187330
# Train Epoch: 37 [80000/84843 (94%)]	Loss: 0.168353
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 38 [0/84843 (0%)]	Loss: 0.086124
# Train Epoch: 38 [5000/84843 (6%)]	Loss: 0.085798
# Train Epoch: 38 [10000/84843 (12%)]	Loss: 0.097848
# Train Epoch: 38 [15000/84843 (18%)]	Loss: 0.068279
# Train Epoch: 38 [20000/84843 (24%)]	Loss: 0.122569
# Train Epoch: 38 [25000/84843 (29%)]	Loss: 0.251162
# Train Epoch: 38 [30000/84843 (35%)]	Loss: 0.129641
# Train Epoch: 38 [35000/84843 (41%)]	Loss: 0.262361
# Train Epoch: 38 [40000/84843 (47%)]	Loss: 0.094714
# Train Epoch: 38 [45000/84843 (53%)]	Loss: 0.148121
# Train Epoch: 38 [50000/84843 (59%)]	Loss: 0.114877
# Train Epoch: 38 [55000/84843 (65%)]	Loss: 0.141849
# Train Epoch: 38 [60000/84843 (71%)]	Loss: 0.175827
# Train Epoch: 38 [65000/84843 (77%)]	Loss: 0.252171
# Train Epoch: 38 [70000/84843 (82%)]	Loss: 0.093533
# Train Epoch: 38 [75000/84843 (88%)]	Loss: 0.202700
# Train Epoch: 38 [80000/84843 (94%)]	Loss: 0.108314
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 39 [0/84843 (0%)]	Loss: 0.178850
# Train Epoch: 39 [5000/84843 (6%)]	Loss: 0.196017
# Train Epoch: 39 [10000/84843 (12%)]	Loss: 0.074914
# Train Epoch: 39 [15000/84843 (18%)]	Loss: 0.175108
# Train Epoch: 39 [20000/84843 (24%)]	Loss: 0.138762
# Train Epoch: 39 [25000/84843 (29%)]	Loss: 0.177032
# Train Epoch: 39 [30000/84843 (35%)]	Loss: 0.192961
# Train Epoch: 39 [35000/84843 (41%)]	Loss: 0.096826
# Train Epoch: 39 [40000/84843 (47%)]	Loss: 0.066106
# Train Epoch: 39 [45000/84843 (53%)]	Loss: 0.104195
# Train Epoch: 39 [50000/84843 (59%)]	Loss: 0.114425
# Train Epoch: 39 [55000/84843 (65%)]	Loss: 0.376835
# Train Epoch: 39 [60000/84843 (71%)]	Loss: 0.349683
# Train Epoch: 39 [65000/84843 (77%)]	Loss: 0.173052
# Train Epoch: 39 [70000/84843 (82%)]	Loss: 0.308883
# Train Epoch: 39 [75000/84843 (88%)]	Loss: 0.064228
# Train Epoch: 39 [80000/84843 (94%)]	Loss: 0.250515
# | Validation | val loss  0.29 | val accuracy 83%
# Train Epoch: 40 [0/84843 (0%)]	Loss: 0.193633
# Train Epoch: 40 [5000/84843 (6%)]	Loss: 0.174619
# Train Epoch: 40 [10000/84843 (12%)]	Loss: 0.101371
# Train Epoch: 40 [15000/84843 (18%)]	Loss: 0.046485
# Train Epoch: 40 [20000/84843 (24%)]	Loss: 0.177324
# Train Epoch: 40 [25000/84843 (29%)]	Loss: 0.202190
# Train Epoch: 40 [30000/84843 (35%)]	Loss: 0.095212
# Train Epoch: 40 [35000/84843 (41%)]	Loss: 0.203048
# Train Epoch: 40 [40000/84843 (47%)]	Loss: 0.139987
# Train Epoch: 40 [45000/84843 (53%)]	Loss: 0.071246
# Train Epoch: 40 [50000/84843 (59%)]	Loss: 0.322222
# Train Epoch: 40 [55000/84843 (65%)]	Loss: 0.074208
# Train Epoch: 40 [60000/84843 (71%)]	Loss: 0.233469
# Train Epoch: 40 [65000/84843 (77%)]	Loss: 0.227474
# Train Epoch: 40 [70000/84843 (82%)]	Loss: 0.179350
# Train Epoch: 40 [75000/84843 (88%)]	Loss: 0.097663
# Train Epoch: 40 [80000/84843 (94%)]	Loss: 0.236665
# | Validation | val loss  0.29 | val accuracy 83%
# =========================================================================================
# | End of training | test loss  0.31 | test accuracy 91%
# =========================================================================================
# Text(0.5, 1.0, 'training loss')
